# %% [markdown]
# <a href="https://colab.research.google.com/github/namne21123-ops/Supply-Chain-Learning/blob/main/30Days_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Introduction of Python
# 30days python challenge

print("Hello World")

print(2+3)
print(3-1)
print(2*3)
print(3+2)
print(3-2)
print(3*2)


print(3/2)
print(3**2)
print(3**3)
print(5**2)


print(3%2)
print(5%2)
print(4%2)
print(10%2)

print(3//2)
print(-3//2)


# checking data type
# Out:
# Hello World
# 5
# 2
# 6
# 5
# 1
# 6
# 1.5
# 9
# 27
# 25
# 1
# 1
# 0
# 0
# 1
# -2

# %%
print(type(10))

print(type(3.14))

print(type(1+3j))

print(type('Asebeneh'))

print(type([1, 2, 3]))

print(type({'name': 'Asebeneh'}))

print(type({9.8, 3.14, 2.7}))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
